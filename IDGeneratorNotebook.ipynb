# %% [markdown]
# <a href="https://colab.research.google.com/github/menongo/notebooks/blob/main/IDGeneratorNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mkdir /content/idgen/tmp

# %%
from PIL import Image, ImageDraw, ImageFont

image = Image.new('RGB', (1000, 900), (255, 255, 255))
draw = ImageDraw.Draw(image)
# font = ImageFont.truetype('arial.ttf', size=45)
import random
import os
import datetime
import qrcode

os.system("ID CARD Generator")
fontName = '/content/idgen/fonts/' + 'Arial.ttf'

d_date = datetime.datetime.now()
reg_format_date = d_date.strftime("  %d-%m-%Y\t\t\t\t\t ID CARD Generator\t\t\t\t\t  %I:%M:%S %p")
print('------------------------------------------------------------------------------------------------')
print(reg_format_date)
print('------------------------------------------------------------------------------------------------')

# starting position of the message
print('\n\nAll Fields are Mandatory')


(x, y) = (50, 50)
message = input('\nEnter Your Company Name: ')
company = message
color = 'rgb(0, 0, 0)'
font = ImageFont.truetype(fontName , size=80)
draw.text((x, y), message, fill=color, font=font)

# adding an unique id number. You can manually take it from user
(x, y) = (600, 75)
idno = random.randint(191022001, 191022010)
message = str('ID ' + str(idno))
color = 'rgb(0, 0, 0)'  # black color
font = ImageFont.truetype(fontName, size=60)
draw.text((x, y), message, fill=color, font=font)

(x, y) = (50, 250)
message = input('Enter Your Full Name: ')
name = message
color = 'rgb(0, 0, 0)'  # black color
font = ImageFont.truetype(fontName, size=45)
draw.text((x, y), message, fill=color, font=font)

(x, y) = (50, 350)
message = input('Enter Your Gender: ')
color = 'rgb(0, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=font)
(x, y) = (250, 350)
message = input('Enter Your Age: ')
color = 'rgb(0, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=font)

(x, y) = (50, 450)
message = input('Enter Your Date Of Birth: ')
color = 'rgb(0, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=font)

(x, y) = (50, 550)
message = input('Enter Your Blood Group: ')
color = 'rgb(255, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=font)

(x, y) = (50, 650)
message = input('Enter Your Mobile Number: ')
temp = message
color = 'rgb(0, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=font)

(x, y) = (50, 750)
message = input('Enter Your Address: ')
color = 'rgb(0, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=font)

# save the edited image

image.save(str(name) + '.png')

img = qrcode.make(str(company) + str(idno))  # this info. is added in QR code, also add other things
img.save(str(idno) + '.bmp')

til = Image.open(name + '.png')
im = Image.open(str(idno) + '.bmp')  # 25x25
til.paste(im, (600, 350))
til.save(name + '.png')

print(('\n\n\nYour ID Card Successfully created in a PNG file ' + name + '.png'))
eval(input('\n\n Please Press any key to Close program.'))

# End
# Out:
# ------------------------------------------------------------------------------------------------
#   30-09-2023					 ID CARD Generator					  04:31:48 PM
# ------------------------------------------------------------------------------------------------
#
#
# All Fields are Mandatory
#
# Enter Your Company Name: CAS ALUMINI
# Enter Your Full Name: MANJUSH MENON
# Enter Your Gender: MALE
# Enter Your Age: 44
# Enter Your Date Of Birth: 1979
# Enter Your Blood Group: AB
# Enter Your Mobile Number: 99999999
# Enter Your Address: 1234 Main St
#
#
#
# Your ID Card Successfully created in a PNG file MANJUSH MENON.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-dea7d1ae5007> in <cell line: 89>()
#      87
#      88 print(('\n\n\nYour ID Card Successfully created in a PNG file ' + name + '.png'))
# ---> 89 eval(input('\n\n Please Press any key to Close program.'))
# ...

# %%
# pip install Pillow
# pip install qrcode
# pip install DateTime
# pip install random2

# mkdir /content/idgen/fonts/
# mkdir /content/idgen/output/
# mkdir /content/idgen/tmp/

from PIL import Image, ImageDraw, ImageFont

# import necessary packages into notebook
import random
import os
import datetime
import qrcode

# new image canvas - need to adjust it accordingly to the ID format discussed
image = Image.new('RGB', (1000, 900), (255, 255, 255))

# create a brand new membership card image to draw
draw = ImageDraw.Draw(image)

fontFolder = '/content/idgen/fonts/'
imageFolder = '/content/idgen/output/'
tmpFolder = '/content/idgen/tmp/'

# copy the font file to the font folder defined above
# font name
fontName = 'Arial.ttf'

# font size for the card's title, id and elements
titleFontSize=80
idFontSize=60
elementsFontSize=45

#define the font objects to use for each type of fields
titleFont = ImageFont.truetype(fontFolder + fontName , size=titleFontSize)
idFont = ImageFont.truetype(fontFolder + fontName , size=idFontSize)
elementsFont = ImageFont.truetype(fontFolder + fontName , size=elementsFontSize)



d_date = datetime.datetime.now()
reg_format_date = d_date.strftime("%d-%m-%Y\t\t\t\t\t ALACASM CARD GENERATOR\t\t\t\t\t%I:%M:%S %p")
print('------------------------------------------------------------------------------------------------')
print(reg_format_date)
print('------------------------------------------------------------------------------------------------')

# starting position of the message
print('\n\nAll Fields are Mandatory')

# co-ordinates for title
(x, y) = (50, 50)
message = input('\nEnter the title for card: ')
cardTitle = message
color = 'rgb(0, 0, 0)'
draw.text((x, y), message, fill=color, font=titleFont)

# co-ordinates for ID
(x, y) = (600, 75)
# currently this program uses a ramdom number for ID number
idno = random.randint(191022001, 191022010)
message = str('ID ' + str(idno))
color = 'rgb(0, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=idFont)

(x, y) = (50, 250)
message = input('Enter Your Full Name: ')
name = message
color = 'rgb(0, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=elementsFont)

(x, y) = (50, 350)
message = input('Enter Your Gender: ')
color = 'rgb(0, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=elementsFont)

(x, y) = (250, 350)
message = input('Enter Your Age: ')
color = 'rgb(0, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=elementsFont)

(x, y) = (50, 450)
message = input('Enter Your Date Of Birth: ')
color = 'rgb(0, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=elementsFont)

(x, y) = (50, 550)
message = input('Enter Your Blood Group: ')
color = 'rgb(255, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=elementsFont)

(x, y) = (50, 650)
message = input('Enter Your Mobile Number: ')
temp = message
color = 'rgb(0, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=elementsFont)

(x, y) = (50, 750)
message = input('Enter Your Address: ')
color = 'rgb(0, 0, 0)'  # black color
draw.text((x, y), message, fill=color, font=elementsFont)

# save the image
image.save(imageFolder + str(name) + '.png')

# add ingo into the QR code; use tmp folder to create the tmp qr file
img = qrcode.make(str(company) + str(idno))
img.save(tmpFolder + str(idno) + '.bmp')

# open the card image/canvas
til = Image.open(imageFolder + name + '.png')

# open the QR code image
qrc = Image.open(tmpFolder + str(idno) + '.bmp')  # 25x25

# paset QR code in the card canvas
til.paste(qrc, (600, 350))

# save the card image again as PNG - this time it will have QR code
til.save(imageFolder + name + '.png')

print(('\n\n\nMembership card was generated successfully' + imageFolder + name + '.png'))

# eval(input('\n\n EXIT!'))
# End
# Out:
# ------------------------------------------------------------------------------------------------
# 30-09-2023					 ALACASM CARD GENERATOR					05:52:15 PM
# ------------------------------------------------------------------------------------------------
#
#
# All Fields are Mandatory
#
# Enter the title for card: CASMVK TITLE
# Enter Your Full Name: AAAAA
# Enter Your Gender: BBBBB
# Enter Your Age: CCCCC
# Enter Your Date Of Birth: DDDDD
# Enter Your Blood Group: EEEEE
# Enter Your Mobile Number: FFFFF
# Enter Your Address: GGGG
#
#
#
# Membership card was generated successfully/content/idgen/output/AAAAA.png
